# %%
from tradinglab.downloader import *

# %%
stocks = stocks_manager(archive='FMIB_prices')
stocks.status()
# Out:
# First available record: 2019-01-02
# Last available record:  2019-12-27
# Total number of records: 359

# %%
ticks = stocks.ticker_list

# %%
stocks.downlaod('2019-1-1', '2019-12-29', ticks=ticks)
# Out:
# ...
# #251 records downloaded

# %%
stocks.data.tail()
# Out:
# Attributes Adj Close                                                  \
# Symbols       A2A.MI     AMP.MI     ATL.MI     AZM.MI BAMI.MI BPE.MI
# Date
# 2019-12-18    1.6560  25.700001  21.950001  21.540001   2.028  4.526
# 2019-12-19    1.6805  25.500000  22.139999  21.500000   2.049  4.560
# 2019-12-20    1.7030  25.820000  22.070000  21.500000   2.038  4.516
# 2019-12-23    1.6920  25.840000  21.000000  21.469999   2.025  4.510
# 2019-12-27    1.6980  25.799999  21.150000  21.200001   2.004  4.454
#
# Attributes                                        ...      Volume              \
# Symbols        BZU.MI CNHI.MI CPR.MI      DIA.MI  ...      SPM.MI      SRG.MI
# Date                                              ...
# 2019-12-18  22.549999   9.876  8.195  116.699997  ...   4889395.0  11089830.0
# 2019-12-19  22.070000   9.766  8.140  117.599998  ...   5206117.0  12102100.0
# 2019-12-20  22.040001   9.890  8.255  118.199997  ...   8580122.0  27295501.0
# ...
